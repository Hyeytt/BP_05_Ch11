# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyeytt/BP_05_Ch11/blob/main/BP_05_EX_Ch11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 사용자가 입력한 텍스트 파일을 열어서 파일 안에 글자가 몇 개나 있는지를 계산하는 프로그램을 작성하라.

# %%
from google.colab import files                 # 내 컴퓨터의 파일을 코랩상에 업로드해서 처리가 가능하게 하는 문장이다
uploaded = files.upload()                      # 내 컴퓨터의 파일을 업로드한다 
filename = input("파일 이름을 입력하세요: ").strip()    # input함수를 사용하여 파일의 이름을 입력받아 filename이라는 변수에 저장한다
infile = open(filename, "r")                           # 읽기모드로 파일을 열어 변수 infile에 저장한다
count = 0                                              # count값을 0으로 초기화시킨다 
for line in infile:
  for ch in line:
    count += 1                                       # 파일 안의 글자의 개수를 하나하나씩 추가해가며 센다
print("파일 안에는 총 ", count , "개의 글자가 있습니다.")  # print 함수를 사용하여 문장을 출력한다 
infile.close()                                     # 파일을 닫게하는 문장이다.
# Out:
#      <input type="file" id="files-76e3d70d-40f9-4732-8c8f-688ab1385ede" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76e3d70d-40f9-4732-8c8f-688ab1385ede">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 2. 사용자로부터 파일 이름과 삭제할 문자열을 입력받는다. 파일을 열어서 사용자가 원하는 문자열을 삭제한 후에 다시 파일에 쓴다.

# %%
from google.colab import files        # 내 컴퓨터의 파일을 코랩상에 업로드해서 처리가 가능하게 하는 문장이다
uploaded = files.upload()              # 내 컴퓨터의 파일을 업로드한다
infilename = input("파일 이름을 입력하시오: ").strip()    # input함수를 사용하여 파일의 이름을 입력받아 infilename이라는 변수에 저장한다 
infile = open(infilename, "r")                          # "r"이라는 읽기모드로 파일을 열어 infile에 저장한다  
file_s = infile.read()                                   # infile에 저장된 파일을 읽는다 
removed_s = input("삭제할 문자열을 입력하시오: ").strip()   # input함수를 사용하여 입력받은 문자열을 removed_s에 저장한다
modified_s = file_s.replace(removed_s, "")                  # 연 파일에서 윗 문장에서 입력받은 문장을 삭제한다     
infile.close()                                              # 파일을 닫는다 
outfile = open(infilename, "w")                             # 쓰기모드로 같은 이름의 파일을 연다 
print(modified_s, file = outfile, end = "")                 # 변경된 내용을 입력한다 
print("변경된 파일이 저장되었습니다.")                      # print함수를 이용해 "변경된 파일이 저장되었습니다."라는 문장을 출력한다
outfile.close()                                             # 파일을 닫는다
# Out:
#      <input type="file" id="files-7bddb75c-c3d4-434e-beba-494bb0d2ab1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7bddb75c-c3d4-434e-beba-494bb0d2ab1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 3. 사용자가 입력하는 파일에 있는 각 문자들이 나타내는 빈도를 계산하는 프로그램을 작성하라.

# %%
from google.colab import files              # 내 컴퓨터의 파일을 코랩상에 업로드해서 처리가 가능하게 하는 문장이다
uploaded = files.upload()                    # 내 컴퓨터의 파일을 업로드한다

infilename = input("파일 이름을 입력하시오: ").strip()      # input함수를 사용하여 파일의 이름을 입력받아 infilename이라는 변수에 저장한다
infile = open(filename, "r")                                # "r"이라는 읽기모드로 파일을 열어 infile에 저장한다 
for line in infile:                                        # for에 파일을 지정하면 파일의 내용을 한 줄씩 읽어서 변수에 저장한다는 문장이다 

    def countLine(line, counter):                         # 줄의 개수를 센다                     
      for ch in line:                                       
        if ch.isalpha():                                     # 알파벳을 확인하는 함수인 isalpha()를 사용하여 줄에 문자가 있는지 확인한다
          if ch in counter:                                   # 만약 단어가 있다면                              
            counter[ch] = counter[ch] + 1                     # 개수에 추가하고
        else:                                                 # 그렇지 않다면 
            counter[ch] = 1                                   
fname = input("입력 파일 이름: ").strip()                     # input함수를활용하여 파일 이름을 입력받아 fname에 저장한다
infile = open(fname, "r")                                     # fnamedp 저장한 파일을 읽기모드로 연다.
my_dict = { }                                                 # 딕셔너리 형식을 사용한다
for line in infile:                                           
 countLine(line, my_dict)
print(my_dict)
infile.close()                                                # 파일을 닫는다
# Out:
#      <input type="file" id="files-ae02aeeb-914f-4228-93ac-e5d8f8f46d3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae02aeeb-914f-4228-93ac-e5d8f8f46d3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 4. 파이썬에서는 객체를 파일에 저장할 수 있다. pickle 모듈을 사용하여서 정수 12, 실수3.14, 리스트 [1, 2, 3, 4, 5]를 이진 파일 “test.dat”에 저장하였다가 다시 읽는 프로그램을 작성하고 테스트하라.

# %% [markdown]
#     import pickle
#     outfile = open("test.dat", "wb")
#     pickle.dump(12, outfile)
#     pickle.dump(3.14, outfile)
#     pickle.dump([1, 2, 3, 4, 5], outfile)
#     outfile.close()
#     infile = open("test.dat", "rb")
#     print(pickle.load(infile))
#     print(pickle.load(infile))
#     print(pickle.load(infile))
#     infile.close()

# %% [markdown]
# # 5. 텍스트 파일 “data.txt”에 실수값들이 저장되어 있다고 가정하자. 한 줄에 하나의 실수만 저장되어 있다. 예를 들면 다음과 같다.
# # 이 파일을 읽어서 합계와 평균을 계산한 후에 이것을“output.txt” 파일에 다음과 같이 저장하는 프로그램을 작성하라.

# %%
from google.colab import files # 내 컴퓨터의 파일을 코랩에 업로드해서
uploaded = files.upload() # 처리 하는 부분입니다.


inFileName = input("입력 파일 이름: ")
outFileName = input("출력 파일 이름: ")
infile = open(inFileName, "r")
outfile = open(outFileName, "w")
total = 0.0
count = 0
line = infile.readline()
while line != "" :
 value = float(line)
 total = total + value
 count = count + 1
 line = infile.readline()
outfile.write("합계="+ str(total)+"\n")
avg = total / count
outfile.write("평균="+ str(avg)+"\n")
infile.close()
outfile.close()
# Out:
#      <input type="file" id="files-466d5215-6d12-4d35-802c-f2fdf8ea1fd9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-466d5215-6d12-4d35-802c-f2fdf8ea1fd9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 6.tkinter를 사용하여 다음과 같은 사용자 인터페이스를 만든다. ‘추가’ 버튼을 누르면 사용자가 입력한 이름과 전화번호 리스트가 파일 “phone_book.dat”에 저장된다. “파일 읽기’를 누르면 파일“phone_book.dat”에서 이름과 전화 번호를 읽어오는 프로그램을 작성하라.
